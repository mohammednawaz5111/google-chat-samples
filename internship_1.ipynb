# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammednawaz5111/google-chat-samples/blob/main/internship_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as p
import numpy as np

# %%
d=p.read_csv("disney_movies.csv")
d.head
print(d.isnull())
# Out:
#      movie_title  release_date  genre  mpaa_rating  total_gross  \
# 0          False         False  False        False        False
# 1          False         False  False        False        False
# 2          False         False  False        False        False
# 3          False         False  False        False        False
# 4          False         False  False        False        False
# ..           ...           ...    ...          ...          ...
# 574        False         False  False        False        False
# 575        False         False  False        False        False
# 576        False         False  False        False        False
# 577        False         False  False        False        False
# 578        False         False  False        False        False
#
#      inflation_adjusted_gross
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...

# %%
d.sample(6)
# Out:
#               movie_title release_date              genre mpaa_rating  \
# 353  The Royal Tenenbaums   2001-12-14       Black Comedy           R
# 266  George Of The Jungle   1997-07-16             Comedy          PG
# 411       The Incredibles   2004-11-05          Adventure          PG
# 183        Color of Night   1994-08-19  Thriller/Suspense           R
# 456         The Invisible   2007-04-27  Thriller/Suspense       PG-13
# 230      Before and After   1996-02-23              Drama       PG-13
#
#      total_gross  inflation_adjusted_gross
# 353     52353636                  76758193
# 266    105263257                 193326632
# 411    261441092                 354488708
# 183     19750470                  40804816
# 456     20568319                  25202168
# 230      8642118                  16482589

# %%
d.isnull().sum()
# Out:
# movie_title                  0
# release_date                 0
# genre                       17
# mpaa_rating                 56
# total_gross                  0
# inflation_adjusted_gross     0
# dtype: int64

# %%
a=d.isnull()
a
# Out:
#      movie_title  release_date  genre  mpaa_rating  total_gross  \
# 0          False         False  False        False        False
# 1          False         False  False        False        False
# 2          False         False  False        False        False
# 3          False         False  False        False        False
# 4          False         False  False        False        False
# ..           ...           ...    ...          ...          ...
# 574        False         False  False        False        False
# 575        False         False  False        False        False
# 576        False         False  False        False        False
# 577        False         False  False        False        False
# 578        False         False  False        False        False
#
#      inflation_adjusted_gross
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...

# %%
d.dropna()
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
# how many total missing values do we have?
total = np.product(d.shape)
t_missing= a.sum()

# percent of data that is missing
k=(t_missing/total) * 100
k
# Out:
# movie_title                 0.000000
# release_date                0.000000
# genre                       0.489349
# mpaa_rating                 1.611975
# total_gross                 0.000000
# inflation_adjusted_gross    0.000000
# dtype: float64

# %%
d.fillna(method = 'bfill', axis=0).fillna(0)
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
from matplotlib import pyplot as plt
_df_24.plot(kind='scatter', x='total_gross', y='inflation_adjusted_gross', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_20['total_gross'].plot(kind='hist', bins=20, title='total_gross')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_22.groupby('genre').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
